# %%
## Import necessary modules
import pandas as pd
import os
import yaml
import numpy as np
import matplotlib.pyplot as plt
import reporting_functions as rf

# %% [markdown]
# ## Plot characteristic loads from yaml file

# %%
## Define output files to be plotted
output_directory = 'outputs/17_save_data_first/iteration_0'
yaml_file = 'characteristic_loads.yaml'

# %%
with open(os.path.join(output_directory, yaml_file), 'r') as file:
    data = yaml.safe_load(file)

# %%
rf.plot_characteristic_loads(data)

# %% [markdown]
# ## Plot binned data

# %%
#WIP

# df = pd.read_pickle(os.path.join(output_directory, file))
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df = pd.read_pickle(os.path.join(output_directory, file))
#
# File ~/.conda-envs/weis-env/lib/python3.12/site-packages/pandas/io/pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     199     with warnings.catch_warnings(record=True):
#     200         # We want to silence any warnings about, e.g. moved modules.
#     201         warnings.simplefilter("ignore", Warning)
# --> 202         return pickle.load(handles.handle)
#     203 except excs_to_catch:
#     204     # e.g.
#     205     #  "No module named 'pandas.core.sparse.series'"
#     206     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#     207     return pc.load(handles.handle, encoding=None)
#
# UnpicklingError: invalid load key, '\x27'.

# %%
rf.plot_time_series(df)

# %%
df
# Out:
#       Time  Wind1VelX  Wind1VelY  Wind1VelZ     Azimuth  BldPitch1  BldPitch2  \
# 0  29.9875   6.712143        0.0        0.0   53.294117  48.573264  48.573264
# 1  49.9875  10.034107        0.0        0.0  196.650672  25.156029  25.156029
#
#    BldPitch3  GenSpeed   IPDefl1  ...       RootMc3    TipDc1    TipDc2  \
# 0  48.573264  0.705104 -1.137681  ...  15612.915958  1.204537  0.706549
# 1  25.156029  2.483825  0.137896  ...  12418.833004  0.928657  1.136632
#
#      TipDc3        TwrBsM  PtfmOffset   NcIMUTA  dBldPitch1  dBldPitch2  \
# 0  1.398810  83942.963440    0.716131  0.169543   -1.261667   -1.261667
# 1  0.935473  96104.694802    1.685020  0.129273   -0.917359   -0.917359
#
#    dBldPitch3
# 0   -1.261667
# 1   -0.917359
#
# [2 rows x 456 columns]

# %%
df['Wind1VelX']
# Out:
#                              min        max       std       mean     median  \
# DLC1.1_0_testbench_0    6.985347   9.593115  0.557093   8.012155   7.941261
# DLC1.1_0_testbench_1    6.915847   9.650239  0.554559   8.008705   7.918468
# DLC1.1_0_testbench_2    6.997097   9.334304  0.503878   8.008710   7.979386
# DLC1.1_0_testbench_3   12.724619  17.220558  0.827380  15.016712  14.921613
# DLC1.1_0_testbench_4   12.509251  18.062607  1.389581  15.022371  14.962576
# DLC1.1_0_testbench_5   12.941975  17.209631  0.993771  15.016703  15.014798
# DLCRamp_1_testbench_0   5.000000  11.000000  1.900745   8.374766   8.428572
#
#                              abs  integrated
# DLC1.1_0_testbench_0    9.593115   80.092061
# DLC1.1_0_testbench_1    9.650239   80.092105
# DLC1.1_0_testbench_2    9.334304   80.092176
# DLC1.1_0_testbench_3   17.220558  150.172676
# DLC1.1_0_testbench_4   18.062607  150.172751
# DLC1.1_0_testbench_5   17.209631  150.172590
# ...

# %%
plot_time_series(df)
