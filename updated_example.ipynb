# %% [markdown]
# ### pCrunch Update
#
# Jake Nunemaker
#
# Last Updated: 02/08/2021

# %%
import os
from fnmatch import fnmatch

import numpy as np
import pandas as pd
import ruamel.yaml as ry

from pCrunch import LoadsAnalysis, PowerProduction
from pCrunch.io import load_FAST_out
from pCrunch.utility import save_yaml, get_windspeeds, convert_summary_stats

def valid_extension(fp):
    return any([fnmatch(fp, ext) for ext in ["*.outb", "*.out"]])

# %% [markdown]
# #### Project Directory

# %%
output_dir = "/Users/jnunemak/Projects/pCrunch/BAR10/rank_0/"
results_dir = os.path.join(output_dir, "results")
save_results = True

outfiles = [
    os.path.join(output_dir, f) for f in os.listdir(output_dir)
    if valid_extension(f)
]

print(f"Found {len(outfiles)} files.")
# Out:
# Found 48 files.

# %% [markdown]
# #### Interacting with output files

# %%
# The new framework provides an object oriented framework to interact with
# output files. The easiest way to use this is to use the 'load_FAST_out' function.

outputs = load_FAST_out(outfiles[:3])
outputs
# Out:
# [<pCrunch.io.openfast.OpenFASTBinary at 0x7fdb1c30a890>,
#  <pCrunch.io.openfast.OpenFASTBinary at 0x7fdb1c308090>,
#  <pCrunch.io.openfast.OpenFASTBinary at 0x7fdaea1b42d0>]

# %%
# An instance of 'OpenFASTBinary' (or 'OpenFASTAscii' if applicable) is created.
# The instance stores the raw data but also provides many useful methods for
# interacting with the data:

# print(outputs[0].data)
# print(outputs[0].time)
# print(outputs[0].channels)
# print(outputs[0].maxima)
# print(outputs[0].stddevs)

# Individual channel time series can also be accessed with dict style indexing:
outputs[0]["Wind1VelX"]
# Out:
# array([12.742136  , 12.7732935 , 12.80445099, ...,  9.66378784,
#         9.49098396,  9.31818104])

# %% [markdown]
# #### pCrunch Configuration

# %%
# Channel magnitudes are defined in a dict:
magnitude_channels = {
    "RootMc1": ["RootMxc1", "RootMyc1", "RootMzc1"],
    "RootMc2": ["RootMxc2", "RootMyc2", "RootMzc2"],
    "RootMc3": ["RootMxc3", "RootMyc3", "RootMzc3"],
}

# Define channels (and their fatigue slopes) in a dict:
fatigue_channels = {
    "RootMc1": 10,
    "RootMc2": 10,
    "RootMc3": 10
}

# Define channels to save extreme data in a list:
channel_extremes = [
    "RotSpeed",
    "RotThrust",
    "RotTorq",
    "RootMc1",
    "RootMc2",
    "RootMc3",
]

# %% [markdown]
# #### Run pCrunch

# %%
# The API has changed and is in more of an object oriented framework.
la = LoadsAnalysis(
    outfiles[:5],                           # The primary input is a list of output files
    magnitude_channels=magnitude_channels,  # All of the following inputs are optional
    fatigue_channels=fatigue_channels,      # 
    extreme_channels=channel_extremes,      #
    trim_data=(0,),                         # If 'trim_data' is passed, all input files will
)                                           # be trimmed to (tmin, tmax(optional))

la.process_outputs(cores=4)                 # Once LoadsAnalysis is configured, process outputs with
                                            # `process_outputs`. `cores` is optional but will trigger parallel processing if configured

# %% [markdown]
# #### Outputs

# %%
# The summary stats per each file are here:
la.summary_stats
# Out:
#                     Wind1VelX  Wind1VelY Wind1VelZ   Azimuth  BldPitch1  \
#                           min        min       min       min        min
# BAR10_0_IEC_13.outb  7.331778  -6.869149 -4.288182  0.000772   6.118227
# BAR10_0_IEC_44.outb  8.667914 -11.789858 -6.978124  0.005214  12.433221
# BAR10_0_IEC_05.outb  2.856447  -3.947478 -2.561280  0.005236  -0.000711
# BAR10_0_IEC_29.outb -1.641610  -7.189809 -5.436992  0.013818  -0.002101
# BAR10_0_IEC_09.outb  5.212037  -5.217299 -3.432661  0.001330   1.648894
#
#                      BldPitch2  BldPitch3     LSSTipMys     LSSTipMzs  \
#                            min        min           min           min
# BAR10_0_IEC_13.outb   6.118227   6.118227 -13111.493164 -12674.125977
# BAR10_0_IEC_44.outb  12.433221  12.433221 -21819.613281 -25325.222656
# BAR10_0_IEC_05.outb  -0.000711  -0.000711  -9256.007812  -6742.917969
# BAR10_0_IEC_29.outb  -0.002101  -0.002101 -14932.917969 -13265.808594
# BAR10_0_IEC_09.outb   1.648894   1.648894 -13388.862305 -10368.466797
#
#                       LSShftFys  ...     RtAeroFyh     RtAeroFzh      BLFLAP1  \
#                             min  ...    integrated    integrated   integrated
# BAR10_0_IEC_13.outb -165.555588  ... -5.922870e+06 -4.352968e+06 -7508.041606
# BAR10_0_IEC_44.outb -385.993225  ... -3.907670e+06  5.864540e+07  3108.495682
# BAR10_0_IEC_05.outb  -79.591148  ... -1.975618e+06  2.786134e+06 -3493.678004
# BAR10_0_IEC_29.outb -126.139671  ...  4.020631e+06  2.204353e+07  -515.067738
# BAR10_0_IEC_09.outb -105.768608  ...  1.228290e+07  4.560042e+06  3974.905589
#
#                          BLFLAP2      BLFLAP3        GenPwr         GenTq  \
#                       integrated   integrated    integrated    integrated
# BAR10_0_IEC_13.outb -7538.544022 -6856.646326 -1.709636e+05      0.000000
# BAR10_0_IEC_44.outb -4699.187800 -6618.763643 -1.633114e+05      0.000000
# BAR10_0_IEC_05.outb  4489.294780  1109.401172 -9.360385e+05  -9904.555098
# BAR10_0_IEC_29.outb  7287.945109 -6500.772840  1.177895e+06  14297.999188
# BAR10_0_IEC_09.outb -3006.706357 -5555.861299 -1.939158e+05    189.144435
#
#                           RootMc1       RootMc2       RootMc3
#                        integrated    integrated    integrated
# BAR10_0_IEC_13.outb  2.066127e+06  6.123670e+06  5.847567e+06
# BAR10_0_IEC_44.outb -4.242427e+06  2.036104e+06  3.784935e+06
# BAR10_0_IEC_05.outb -2.828652e+06 -1.116475e+06 -6.598650e+06
# BAR10_0_IEC_29.outb  3.440799e+06  1.619509e+05 -1.402842e+06
# BAR10_0_IEC_09.outb -2.989209e+06 -2.894136e+05  7.052371e+06
#
# [5 rows x 1104 columns]

# %%
# These are indexable by channel, stat:
la.summary_stats["Wind1VelX"]
# Out:
#                           min        max       std       mean        abs  \
# BAR10_0_IEC_13.outb  7.331778  23.038691  2.653315  14.787289  23.038691
# BAR10_0_IEC_44.outb  8.667914  36.075912  4.272328  23.286647  36.075912
# BAR10_0_IEC_05.outb  2.856447  11.880972  1.555660   6.877674  11.880972
# BAR10_0_IEC_29.outb -1.641610  17.482164  3.332014   7.058670  17.482164
# BAR10_0_IEC_09.outb  5.212037  17.023720  2.103185  10.822902  17.023720
#
#                       integrated
# BAR10_0_IEC_13.outb -3692.376680
# BAR10_0_IEC_44.outb -1881.130931
# BAR10_0_IEC_05.outb -2227.173018
# BAR10_0_IEC_29.outb -1966.393449
# BAR10_0_IEC_09.outb -2934.333147

# %%
la.summary_stats[("Wind1VelX", 'min')]
# Out:
# BAR10_0_IEC_13.outb    7.331778
# BAR10_0_IEC_44.outb    8.667914
# BAR10_0_IEC_05.outb    2.856447
# BAR10_0_IEC_29.outb   -1.641610
# BAR10_0_IEC_09.outb    5.212037
# Name: (Wind1VelX, min), dtype: float64

# %%
# Or by file
la.summary_stats.loc["BAR10_0_IEC_13.outb"]
# Out:
# Wind1VelX  min           7.331778e+00
# Wind1VelY  min          -6.869149e+00
# Wind1VelZ  min          -4.288182e+00
# Azimuth    min           7.724802e-04
# BldPitch1  min           6.118227e+00
#                              ...
# GenPwr     integrated   -1.709636e+05
# GenTq      integrated    0.000000e+00
# RootMc1    integrated    2.066127e+06
# RootMc2    integrated    6.123670e+06
# RootMc3    integrated    5.847567e+06
# Name: BAR10_0_IEC_13.outb, Length: 1104, dtype: float64

# %%
# Damage equivalent loads are found here:
la.DELs
# Out:
#                           RootMc1       RootMc2       RootMc3
# BAR10_0_IEC_13.outb  17155.972672  18123.882926  18975.048930
# BAR10_0_IEC_44.outb  20769.760533  20173.288148  20931.456407
# BAR10_0_IEC_05.outb  12965.959096  12840.962463  13141.212547
# BAR10_0_IEC_29.outb  17868.450676  17151.796573  16319.655247
# BAR10_0_IEC_09.outb  15761.531479  16148.632706  16634.678742

# %%
# Extreme events:
la.extreme_events
# Out:
# {'RotSpeed': [{'time': 685.0500000000001,
#    'RotSpeed': 8.59638500213623,
#    'RotThrust': 556.005126953125,
#    'RotTorq': 6768.57666015625,
#    'RootMc1': 14070.55579269342,
#    'RootMc2': 17947.08235471186,
#    'RootMc3': 17004.08210931144},
#   {'time': 283.0,
#    'RotSpeed': 9.073287963867188,
#    'RotThrust': 630.1870727539062,
#    'RotTorq': 6677.99755859375,
#    'RootMc1': 14259.785796075768,
#    'RootMc2': 12513.589342673744,
#    'RootMc3': 13571.727943383383},
#   {'time': 448.82,
#    'RotSpeed': 7.822919845581055,
#    'RotThrust': 1103.539794921875,
#    'RotTorq': 6732.35986328125,
#    'RootMc1': 31848.65546017486,
#    'RootMc2': 22403.73546229115,
#    'RootMc3': 24231.932214343855},
#   {'time': 657.52,
#    'RotSpeed': 8.274258613586426,
#    'RotThrust': 837.1314697265625,
#    'RotTorq': 6777.07470703125,
#    'RootMc1': 28096.38032484325,
#    'RootMc2': 19810.039937813377,
#    'RootMc3': 16020.785348512087},
#   {'time': 688.6,
#    'RotSpeed': 8.304394721984863,
#    'RotThrust': 874.20751953125,
#    'RotTorq': 6731.087890625,
#    'RootMc1': 23314.400481013094,
#    'RootMc2': 24576.99486155545,
#    'RootMc3': 21569.828991832623}],
#  'RotThrust': [{'time': 649.91,
#    'RotSpeed': 7.701016902923584,
#    'RotThrust': 1070.7283935546875,
#    'RotTorq': 10623.466796875,
#    'RootMc1': 23111.66399753457,
#    'RootMc2': 30106.701451153705,
#    'RootMc3': 21202.919380642412},
#   {'time': 275.68,
#    'RotSpeed': 7.767523765563965,
#    'RotThrust': 1228.59619140625,
#    'RotTorq': 13663.0341796875,
#    'RootMc1': 25461.153319672543,
#    'RootMc2': 26741.21378299125,
#    'RootMc3': 17272.626038120994},
#   {'time': 432.15000000000003,
#    'RotSpeed': 7.6614556312561035,
#    'RotThrust': 1264.3551025390625,
#    'RotTorq': 6983.3388671875,
#    'RootMc1': 31116.59699619391,
#    'RootMc2': 26069.26259501829,
#    'RootMc3': 28836.810483705318},
#   {'time': 651.13,
#    'RotSpeed': 7.990036487579346,
#    'RotThrust': 1464.6002197265625,
#    'RotTorq': 7789.10009765625,
#    'RootMc1': 29155.085388642718,
#    'RootMc2': 33380.0893320753,
#    'RootMc3': 31866.8168734811},
#   {'time': 682.16,
#    'RotSpeed': 7.959961891174316,
#    'RotThrust': 1402.0526123046875,
#    'RotTorq': 8405.0,
#    'RootMc1': 26420.49406534126,
#    'RootMc2': 27057.79034883098,
#    'RootMc3': 33866.07687586719}],
#  'RotTorq': [{'time': 244.65,
#    'RotSpeed': 8.211743354797363,
#    'RotThrust': 790.530517578125,
#    'RotTorq': 12298.841796875,
#    'RootMc1': 24528.062523960733,
#    'RootMc2': 16644.020375532607,
#    'RootMc3': 17303.081266681274},
#   {'time': 649.44,
#    'RotSpeed': 8.641730308532715,
#    'RotThrust': 433.258056640625,
#    'RotTorq': 20673.87890625,
#    'RootMc1': 13053.466335873642,
#    'RootMc2': 9173.916848751986,
#    'RootMc3': 23321.433906454135},
#   {'time': 437.67,
#    'RotSpeed': 7.721076488494873,
#    'RotThrust': 1185.0179443359375,
#    'RotTorq': 7929.017578125,
#    'RootMc1': 26996.40692657772,
#    'RootMc2': 32460.578342582878,
#    'RootMc3': 23055.134573073414},
#   {'time': 636.88,
#    'RotSpeed': 6.559699058532715,
#    'RotThrust': 1137.0213623046875,
#    'RotTorq': 10855.3603515625,
#    'RootMc1': 26153.667403015515,
#    'RootMc2': 24811.048742659183,
#    'RootMc3': 24441.167465577666},
#   {'time': 437.96,
#    'RotSpeed': 7.990324974060059,
#    'RotThrust': 765.1817626953125,
#    'RotTorq': 9849.8291015625,
#    'RootMc1': 17758.77647370235,
#    'RootMc2': 26889.702862080925,
#    'RootMc3': 11417.531734846181}],
#  'RootMc1': [{'time': 206.54000000000002,
#    'RotSpeed': 7.765745639801025,
#    'RotThrust': 906.7340087890625,
#    'RotTorq': 8318.7978515625,
#    'RootMc1': 31194.522817593195,
#    'RootMc2': 14189.736897644234,
#    'RootMc3': 17880.958572395284},
#   {'time': 441.67,
#    'RotSpeed': 8.05736255645752,
#    'RotThrust': 583.2097778320312,
#    'RotTorq': 9176.5576171875,
#    'RootMc1': 33246.90641133229,
#    'RootMc2': 11046.374895559971,
#    'RootMc3': 10575.91285623994},
#   {'time': 440.7,
#    'RotSpeed': 7.755237102508545,
#    'RotThrust': 1157.44873046875,
#    'RotTorq': 7004.96728515625,
#    'RootMc1': 33705.016752938696,
#    'RootMc2': 23668.90184828401,
#    'RootMc3': 24435.64310369587},
#   {'time': 376.35,
#    'RotSpeed': 7.514404773712158,
#    'RotThrust': 1138.4315185546875,
#    'RotTorq': 6695.30078125,
#    'RootMc1': 35736.31072314672,
#    'RootMc2': 25089.04095728816,
#    'RootMc3': 18809.215976258023},
#   {'time': 206.35000000000002,
#    'RotSpeed': 7.739469528198242,
#    'RotThrust': 1080.920166015625,
#    'RotTorq': 6727.484375,
#    'RootMc1': 34826.67139517586,
#    'RootMc2': 16876.988908251195,
#    'RootMc3': 23268.9466387686}],
#  'RootMc2': [{'time': 666.19,
#    'RotSpeed': 7.980409622192383,
#    'RotThrust': 957.478271484375,
#    'RotTorq': 9448.5107421875,
#    'RootMc1': 19833.477871290743,
#    'RootMc2': 32366.47569238235,
#    'RootMc3': 14837.493452621107},
#   {'time': 142.45,
#    'RotSpeed': 7.9957451820373535,
#    'RotThrust': 765.0256958007812,
#    'RotTorq': 7927.0244140625,
#    'RootMc1': 10009.428731164544,
#    'RootMc2': 31639.7545869675,
#    'RootMc3': 6683.469268890703},
#   {'time': 446.12,
#    'RotSpeed': 7.80462121963501,
#    'RotThrust': 1142.4727783203125,
#    'RotTorq': 6861.7919921875,
#    'RootMc1': 25171.933639978924,
#    'RootMc2': 33382.187381855285,
#    'RootMc3': 22022.785087899723},
#   {'time': 259.53999999999996,
#    'RotSpeed': 7.655827522277832,
#    'RotThrust': 1219.154296875,
#    'RotTorq': 5280.8076171875,
#    'RootMc1': 29369.98125393323,
#    'RootMc2': 34726.880769834854,
#    'RootMc3': 18063.598174024006},
#   {'time': 583.53,
#    'RotSpeed': 7.9705095291137695,
#    'RotThrust': 1091.28466796875,
#    'RotTorq': 7383.95263671875,
#    'RootMc1': 23262.07378020615,
#    'RootMc2': 35286.80801608111,
#    'RootMc3': 18704.080913106813}],
#  'RootMc3': [{'time': 208.96,
#    'RotSpeed': 7.89777946472168,
#    'RotThrust': 989.3090209960938,
#    'RotTorq': 8580.0732421875,
#    'RootMc1': 14548.133277883266,
#    'RootMc2': 18680.248161808082,
#    'RootMc3': 34102.48043242113},
#   {'time': 663.76,
#    'RotSpeed': 7.691674709320068,
#    'RotThrust': 901.3494262695312,
#    'RotTorq': 14678.248046875,
#    'RootMc1': 9912.575953999421,
#    'RootMc2': 18763.10721371065,
#    'RootMc3': 35190.98847494413},
#   {'time': 443.38,
#    'RotSpeed': 7.786472320556641,
#    'RotThrust': 1126.025634765625,
#    'RotTorq': 7132.59765625,
#    'RootMc1': 22371.498803993964,
#    'RootMc2': 24559.73802688619,
#    'RootMc3': 33829.84567038973},
#   {'time': 379.04,
#    'RotSpeed': 7.559158802032471,
#    'RotThrust': 1094.01123046875,
#    'RotTorq': 6801.0400390625,
#    'RootMc1': 24115.58296754194,
#    'RootMc2': 17997.935107088753,
#    'RootMc3': 34575.378392883955},
#   {'time': 208.89,
#    'RotSpeed': 7.8066864013671875,
#    'RotThrust': 1213.90869140625,
#    'RotTorq': 7332.06103515625,
#    'RootMc1': 20579.013536057762,
#    'RootMc2': 23329.18331909447,
#    'RootMc3': 37071.85571172046}]}
